# %%
import numpy as np
import cmath
import math
import matplotlib.pyplot as plt

# %%
aGST = np.loadtxt('PCM_nk/cGST_nk.txt') # reference efficiency
wavelen = aGST[:,0]
n_curve = aGST[:, 1]
k_curve = aGST[:, 2]
print(aGST.shape)
fig, ax1 = plt.subplots(figsize=(9, 5))
ax2 = ax1.twinx()

# plt.plot(wavelen, transmission, color='green', linewidth=0.5, alpha=0.7)
# plt.xlim(1530, 1540)
cGST = np.loadtxt('PCM_nk/aGST_nk.txt') # reference efficiency
print(cGST.shape)
wavelen2 = cGST[150:,0]
c_gst_n_curve = cGST[150:, 1]
c_gst_k_curve = cGST[150:, 2]
line1, = ax1.plot(wavelen, n_curve, color='red')
line2, = ax1.plot(wavelen2, c_gst_n_curve, color='b')

line3, = ax2.plot(wavelen, k_curve, color='red', linestyle='dashed')
line4, = ax2.plot(wavelen2, c_gst_k_curve, color='b', linestyle='dashed')

# ax1.set_xlabel('Wavelength (nm)')
ax1.set_ylabel('n', color='red', fontsize=10)
ax1.tick_params(axis='y', labelcolor='red')
ax2.tick_params(axis='y', labelcolor='b')
ax2.set_ylabel('k', color='b')
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['top'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)

# ax1.legend([line1, line2], ['amorphous', 'amorphous'], loc='lower left')
# ax1.legend([line1, line2], ['amorphous', 'amorphous'], loc='lower left')
# ax2.legend([line3, line4], ['crystaline', 'crystaline'], loc='lower left')
# ax2.legend([line3, line4], ['crystaline', 'crystaline'], loc='lower left')
# Out:
# (544, 3)
# (697, 3)
